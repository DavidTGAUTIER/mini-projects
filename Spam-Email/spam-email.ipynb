# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("white")

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, auc, precision_recall_curve
from sklearn.preprocessing import OneHotEncoder

# %%
source = './src/spambase.data'
spam = pd.read_csv(source, header=None)

# %%
source_name = './src/spambase.names'
spam_names = pd.read_table(source_name, sep=":", header=None, skiprows=33, names=["var", "type"])
spam.columns = list(spam_names["var"]) + ["spam"]
spam
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0               0.00               0.64           0.64           0.0
# 1               0.21               0.28           0.50           0.0
# 2               0.06               0.00           0.71           0.0
# 3               0.00               0.00           0.00           0.0
# 4               0.00               0.00           0.00           0.0
# ...              ...                ...            ...           ...
# 4596            0.31               0.00           0.62           0.0
# 4597            0.00               0.00           0.00           0.0
# 4598            0.30               0.00           0.30           0.0
# 4599            0.96               0.00           0.00           0.0
# 4600            0.00               0.00           0.65           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0              0.32            0.00              0.00                0.00
# 1              0.14            0.28              0.21                0.07
# 2              1.23            0.19              0.19                0.12
# 3              0.63            0.00              0.31                0.63
# 4              0.63            0.00              0.31                0.63
# ...             ...             ...               ...                 ...
# 4596           0.00            0.31              0.00                0.00
# 4597           0.00            0.00              0.00                0.00
# 4598           0.00            0.00              0.00                0.00
# 4599           0.32            0.00              0.00                0.00
# 4600           0.00            0.00              0.00                0.00
#
#       word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0                0.00            0.00  ...        0.000        0.000
# 1                0.00            0.94  ...        0.000        0.132
# 2                0.64            0.25  ...        0.010        0.143
# 3                0.31            0.63  ...        0.000        0.137
# 4                0.31            0.63  ...        0.000        0.135
# ...               ...             ...  ...          ...          ...
# 4596             0.00            0.00  ...        0.000        0.232
# 4597             0.00            0.00  ...        0.000        0.000
# 4598             0.00            0.00  ...        0.102        0.718
# 4599             0.00            0.00  ...        0.000        0.057
# 4600             0.00            0.00  ...        0.000        0.000
#
#       char_freq_[  char_freq_!  char_freq_$  char_freq_#  \
# 0             0.0        0.778        0.000        0.000
# 1             0.0        0.372        0.180        0.048
# 2             0.0        0.276        0.184        0.010
# 3             0.0        0.137        0.000        0.000
# 4             0.0        0.135        0.000        0.000
# ...           ...          ...          ...          ...
# 4596          0.0        0.000        0.000        0.000
# 4597          0.0        0.353        0.000        0.000
# 4598          0.0        0.000        0.000        0.000
# 4599          0.0        0.000        0.000        0.000
# 4600          0.0        0.125        0.000        0.000
#
#       capital_run_length_average  capital_run_length_longest  \
# 0                          3.756                          61
# 1                          5.114                         101
# 2                          9.821                         485
# 3                          3.537                          40
# 4                          3.537                          40
# ...                          ...                         ...
# 4596                       1.142                           3
# 4597                       1.555                           4
# 4598                       1.404                           6
# 4599                       1.147                           5
# 4600                       1.250                           5
#
#       capital_run_length_total  spam
# 0                          278     1
# 1                         1028     1
# 2                         2259     1
# 3                          191     1
# 4                          191     1
# ...                        ...   ...
# 4596                        88     0
# 4597                        14     0
# 4598                       118     0
# 4599                        78     0
# 4600                        40     0
#
# [4601 rows x 58 columns]

# %% [markdown]
# ## Modèle complet

# %%
X = spam.drop(["spam"], axis=1)
y = spam["spam"]

m_complet = LogisticRegression(max_iter=10000).fit(X,y)

# %% [markdown]
# ### Critères de qualité
#
# #### Matrice de confusion

# %%
t = pd.crosstab(m_complet.predict(X), y)
t
# Out:
# spam      0     1
# row_0
# 0      2667   190
# 1       121  1623

# %% [markdown]
# #### $R^2$

# %%
m_complet.score(X, y)
# Out:
# 0.9324059986959357

# %% [markdown]
# #### Courbe ROC et AUC

# %%
fpr, tpr, th = roc_curve(y, pd.DataFrame(m_complet.predict_proba(X))[1])
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(16,8))
plt.title("Courbe ROC")
g = sns.lineplot(x=fpr, y=tpr)
g.set(xlabel="Taux de faux positifs", ylabel="Taux de vrais positifs")
plt.text(.8, .2, "AUC=%0.3f" % roc_auc, fontsize=18)
plt.show()

# %% [markdown]
# #### Courbe Precision/Recall

# %%
pr, rc, th = precision_recall_curve(y, pd.DataFrame(m_complet.predict_proba(X))[1])

plt.figure(figsize=(16,8))
plt.title("Courbe Precision/Recall")
g = sns.lineplot(x=pr, y=rc)
g.set(xlabel="Recall", ylabel="Precision")
plt.show()

# %% [markdown]
# ### Distribution des probabilités pour chaque classe

# %%
probas = pd.DataFrame(m_complet.predict_proba(X), columns=["predit:"+str(v) for v in m_complet.classes_])
probas = probas.assign(spam=spam["spam"])
probas = probas.melt(id_vars="spam")
probas
# Out:
#       spam  variable     value
# 0        1  predit:0  0.402893
# 1        1  predit:0  0.025713
# 2        1  predit:0  0.000018
# 3        1  predit:0  0.239653
# 4        1  predit:0  0.239741
# ...    ...       ...       ...
# 9197     0  predit:1  0.073295
# 9198     0  predit:1  0.036458
# 9199     0  predit:1  0.033009
# 9200     0  predit:1  0.094051
# 9201     0  predit:1  0.042035
#
# [9202 rows x 3 columns]

# %%
sns.catplot(data=probas, kind="box", x="variable", y="value", hue="variable", col="spam", height=7)
plt.show()

# %% [markdown]
# ### Commentaires

# %% [markdown]
# Le modèle complet semble très efficace à prédire si un mail est un spam ou non, avec un $R^2$ de 0.93 (qui est la proportion de mails correctement prédits) et une valeur de $AUC$ de 0.976.

# %% [markdown]
# ## Modèle avec données *binarisées*

# %% [markdown]
# Ici, nous choisissons comme seuil **.1**

# %%
X_bin = spam[['capital_run_length_average', 'capital_run_length_longest', 'capital_run_length_total']]
for v in spam.columns[[any(c[0:4] == cc for cc in ["word", "char"]) for c in spam.columns]]:
    test = spam[[v]] > 0.1
    test.columns = test.columns + "_bin"
    X_bin = pd.concat([X_bin, test], axis=1)
X_bin
# Out:
#       capital_run_length_average  capital_run_length_longest  \
# 0                          3.756                          61
# 1                          5.114                         101
# 2                          9.821                         485
# 3                          3.537                          40
# 4                          3.537                          40
# ...                          ...                         ...
# 4596                       1.142                           3
# 4597                       1.555                           4
# 4598                       1.404                           6
# 4599                       1.147                           5
# 4600                       1.250                           5
#
#       capital_run_length_total  word_freq_make_bin  word_freq_address_bin  \
# 0                          278               False                   True
# 1                         1028                True                   True
# 2                         2259               False                  False
# 3                          191               False                  False
# 4                          191               False                  False
# ...                        ...                 ...                    ...
# 4596                        88                True                  False
# 4597                        14               False                  False
# 4598                       118                True                  False
# 4599                        78                True                  False
# 4600                        40               False                  False
#
#       word_freq_all_bin  word_freq_3d_bin  word_freq_our_bin  \
# 0                  True             False               True
# 1                  True             False               True
# 2                  True             False               True
# 3                 False             False               True
# 4                 False             False               True
# ...                 ...               ...                ...
# 4596               True             False              False
# 4597              False             False              False
# 4598               True             False              False
# 4599              False             False               True
# 4600               True             False              False
#
#       word_freq_over_bin  word_freq_remove_bin  ...  word_freq_re_bin  \
# 0                  False                 False  ...             False
# 1                   True                  True  ...             False
# 2                   True                  True  ...             False
# 3                  False                  True  ...             False
# 4                  False                  True  ...             False
# ...                  ...                   ...  ...               ...
# 4596                True                 False  ...              True
# 4597               False                 False  ...             False
# 4598               False                 False  ...             False
# 4599               False                 False  ...             False
# 4600               False                 False  ...              True
#
#       word_freq_edu_bin  word_freq_table_bin  word_freq_conference_bin  \
# 0                 False                False                     False
# 1                 False                False                     False
# 2                 False                False                     False
# 3                 False                False                     False
# 4                 False                False                     False
# ...                 ...                  ...                       ...
# 4596               True                False                     False
# 4597               True                False                     False
# 4598               True                False                     False
# 4599               True                False                     False
# 4600               True                False                     False
#
#       char_freq_;_bin  char_freq_(_bin  char_freq_[_bin  char_freq_!_bin  \
# 0               False            False            False             True
# 1               False             True            False             True
# 2               False             True            False             True
# 3               False             True            False             True
# 4               False             True            False             True
# ...               ...              ...              ...              ...
# 4596            False             True            False            False
# 4597            False            False            False             True
# 4598             True             True            False            False
# 4599            False            False            False            False
# 4600            False            False            False             True
#
#       char_freq_$_bin  char_freq_#_bin
# 0               False            False
# 1                True            False
# 2                True            False
# 3               False            False
# 4               False            False
# ...               ...              ...
# 4596            False            False
# 4597            False            False
# 4598            False            False
# 4599            False            False
# 4600            False            False
#
# [4601 rows x 57 columns]

# %%
m_binaire = LogisticRegression(max_iter=10000).fit(X_bin, y)

# %% [markdown]
# ### Critères de qualité
#
# #### Matrice de confusion

# %%
pd.crosstab(m_binaire.predict(X_bin), y)
# Out:
# spam      0     1
# row_0
# 0      2677   172
# 1       111  1641

# %% [markdown]
# #### $R^2$

# %%
m_binaire.score(X_bin, y)
# Out:
# 0.9384916322538579

# %% [markdown]
# #### Courbe ROC et AUC

# %%
fpr, tpr, th = roc_curve(y, pd.DataFrame(m_binaire.predict_proba(X_bin))[1])
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(16,8))
plt.title("Courbe ROC")
g = sns.lineplot(x=fpr, y=tpr)
g.set(xlabel="Taux de faux positifs", ylabel="Taux de vrais positifs")
plt.text(.8, .2, "AUC=%0.3f" % roc_auc, fontsize=18)
plt.show()

# %% [markdown]
# #### Courbe Precision/Recall

# %%
pr, rc, th = precision_recall_curve(y, pd.DataFrame(m_binaire.predict_proba(X_bin))[1])

plt.figure(figsize=(16,8))
plt.title("Courbe Precision/Recall")
g = sns.lineplot(x=pr, y=rc)
g.set(xlabel="Recall", ylabel="Precision")
plt.show()

# %% [markdown]
# ### Commentaires

# %% [markdown]
# Le modèle avec les variables binarisées (i.e. transformées en variable binaire) est plus performant encore, avec des valeurs de $R^2$ de 0.94 et de $AUC$ de 0.983. Cette transformation est donc particulièrement intéressante pour ce cas.

# %% [markdown]
# ## Modèles à une variable

# %%
X_tout = pd.concat([X, X_bin.drop(columns=X_bin.columns[:3])], axis=1)
X_tout
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0               0.00               0.64           0.64           0.0
# 1               0.21               0.28           0.50           0.0
# 2               0.06               0.00           0.71           0.0
# 3               0.00               0.00           0.00           0.0
# 4               0.00               0.00           0.00           0.0
# ...              ...                ...            ...           ...
# 4596            0.31               0.00           0.62           0.0
# 4597            0.00               0.00           0.00           0.0
# 4598            0.30               0.00           0.30           0.0
# 4599            0.96               0.00           0.00           0.0
# 4600            0.00               0.00           0.65           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0              0.32            0.00              0.00                0.00
# 1              0.14            0.28              0.21                0.07
# 2              1.23            0.19              0.19                0.12
# 3              0.63            0.00              0.31                0.63
# 4              0.63            0.00              0.31                0.63
# ...             ...             ...               ...                 ...
# 4596           0.00            0.31              0.00                0.00
# 4597           0.00            0.00              0.00                0.00
# 4598           0.00            0.00              0.00                0.00
# 4599           0.32            0.00              0.00                0.00
# 4600           0.00            0.00              0.00                0.00
#
#       word_freq_order  word_freq_mail  ...  word_freq_re_bin  \
# 0                0.00            0.00  ...             False
# 1                0.00            0.94  ...             False
# 2                0.64            0.25  ...             False
# 3                0.31            0.63  ...             False
# 4                0.31            0.63  ...             False
# ...               ...             ...  ...               ...
# 4596             0.00            0.00  ...              True
# 4597             0.00            0.00  ...             False
# 4598             0.00            0.00  ...             False
# 4599             0.00            0.00  ...             False
# 4600             0.00            0.00  ...              True
#
#       word_freq_edu_bin  word_freq_table_bin  word_freq_conference_bin  \
# 0                 False                False                     False
# 1                 False                False                     False
# 2                 False                False                     False
# 3                 False                False                     False
# 4                 False                False                     False
# ...                 ...                  ...                       ...
# 4596               True                False                     False
# 4597               True                False                     False
# 4598               True                False                     False
# 4599               True                False                     False
# 4600               True                False                     False
#
#       char_freq_;_bin  char_freq_(_bin  char_freq_[_bin  char_freq_!_bin  \
# 0               False            False            False             True
# 1               False             True            False             True
# 2               False             True            False             True
# 3               False             True            False             True
# 4               False             True            False             True
# ...               ...              ...              ...              ...
# 4596            False             True            False            False
# 4597            False            False            False             True
# 4598             True             True            False            False
# 4599            False            False            False            False
# 4600            False            False            False             True
#
#       char_freq_$_bin  char_freq_#_bin
# 0               False            False
# 1                True            False
# 2                True            False
# 3               False            False
# 4               False            False
# ...               ...              ...
# 4596            False            False
# 4597            False            False
# 4598            False            False
# 4599            False            False
# 4600            False            False
#
# [4601 rows x 111 columns]

# %%
r2 = []
roc_auc = []
vn = []
fn = []
fp = []
vp = []

for v in X_tout.columns:
    X_seul = X_tout[[v]]
    m_simple = LogisticRegression().fit(X_seul, y)
    r2 = r2 + [m_simple.score(X_seul, y)]
    fpr, tpr, th = roc_curve(y, pd.DataFrame(m_simple.predict_proba(X_seul))[1])
    roc_auc = roc_auc + [auc(fpr, tpr)]
    p = m_simple.predict(X_seul)
    vn = vn + [sum((1 - y) * (1 - p))]
    fn = fn + [sum((1 - y) * p)]
    fp = fp + [sum(y * (1 - p))]
    vp = vp + [sum(y * p)]

df = pd.DataFrame({
    "variable": X_tout.columns,
    "rsquared": r2,
    "auc": roc_auc,
    "vrais_negatifs": vn,
    "faux_negatifs": fn,
    "faux_positifs": fp,
    "vrais_positifs": vp
})

df
# Out:
#               variable  rsquared       auc  vrais_negatifs  faux_negatifs  \
# 0       word_freq_make  0.615953  0.604632            2673            115
# 1    word_freq_address  0.605955  0.378399            2788              0
# 2        word_freq_all  0.618344  0.675314            2551            237
# 3         word_freq_3d  0.612041  0.509340            2785              3
# 4        word_freq_our  0.664638  0.710932            2580            208
# ..                 ...       ...       ...             ...            ...
# 106    char_freq_(_bin  0.605955  0.540887            2788              0
# 107    char_freq_[_bin  0.605955  0.520712            2788              0
# 108    char_freq_!_bin  0.789394  0.781083            2287            501
# 109    char_freq_$_bin  0.775049  0.722952            2701             87
# 110    char_freq_#_bin  0.629211  0.540311            2676            112
#
#      faux_positifs  vrais_positifs
# 0             1652             161
# 1             1813               0
# 2             1519             294
# 3             1782              31
# 4             1335             478
# ..             ...             ...
# 106           1813               0
# 107           1813               0
# 108            468            1345
# 109            948             865
# 110           1594             219
#
# [111 rows x 7 columns]

# %% [markdown]
# #### TOP10 des variables, en se basant sur $R^2$

# %%
df.sort_values(by=["rsquared"], ascending=False).head(10).round(2)
# Out:
#                        variable  rsquared   auc  vrais_negatifs  \
# 108             char_freq_!_bin      0.79  0.78            2287
# 52                  char_freq_$      0.78  0.77            2695
# 109             char_freq_$_bin      0.78  0.72            2701
# 72           word_freq_free_bin      0.76  0.72            2575
# 51                  char_freq_!      0.74  0.83            2624
# 63         word_freq_remove_bin      0.74  0.67            2748
# 6              word_freq_remove      0.74  0.70            2748
# 55   capital_run_length_longest      0.73  0.80            2567
# 80          word_freq_money_bin      0.72  0.65            2744
# 23              word_freq_money      0.72  0.68            2746
#
#      faux_negatifs  faux_positifs  vrais_positifs
# 108            501            468            1345
# 52              93            927             886
# 109             87            948             865
# 72             213            878             935
# 51             164           1029             784
# 63              40           1163             650
# 6               40           1172             641
# 55             221           1042             771
# 80              44           1228             585
# 23              42           1241             572

# %% [markdown]
# #### TOP10 des variables, en se basant sur $AUC$

# %%
df.sort_values(by=["auc"], ascending=False).head(10).round(2)
# Out:
#                        variable  rsquared   auc  vrais_negatifs  \
# 51                  char_freq_!      0.74  0.83            2624
# 55   capital_run_length_longest      0.73  0.80            2567
# 54   capital_run_length_average      0.72  0.79            2596
# 108             char_freq_!_bin      0.79  0.78            2287
# 20               word_freq_your      0.72  0.78            2478
# 52                  char_freq_$      0.78  0.77            2695
# 56     capital_run_length_total      0.66  0.76            2583
# 77           word_freq_your_bin      0.72  0.74            1858
# 15               word_freq_free      0.72  0.73            2663
# 109             char_freq_$_bin      0.78  0.72            2701
#
#      faux_negatifs  faux_positifs  vrais_positifs
# 51             164           1029             784
# 55             221           1042             771
# 54             192           1106             707
# 108            501            468            1345
# 20             310            998             815
# 52              93            927             886
# 56             205           1353             460
# 77             930            355            1458
# 15             125           1186             627
# 109             87            948             865

# %% [markdown]
# #### Commentaires
#
# En se basant sur $R^2$, c'est la présence ou non du caractère "!" qui permet de mieux prédire le fait qu'un mail soit un spam ou non, avec un score de 0.079. Avec l'$AUC$
# , on obtient la même variable, mais en valeur brute.
#
# Cela veut dire que dans presue 80% des cas, il est possible de prédire si un mail est un spam en se basant uniquement sur la présence (importante) de point d'interrogations.
